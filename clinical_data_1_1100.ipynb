# %% [markdown]
# ![alt text](./Cerny_logo_1.jpg)

# %% [markdown]
# # Analysis of Cerny ventilation recordings
#
# ## Processing clinical details
#
# This notebook imports and processes clinical data and exports it into a pickle archive.

# %% [markdown]
# ### Importing the necessary libraries and setting options

# %%
import IPython
import pandas as pd
import numpy as np
import scipy as sp
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn as sk

import os
import sys
import re
import pickle

from scipy import stats
from pandas import Series, DataFrame
from datetime import datetime, timedelta

# %matplotlib inline
matplotlib.style.use('classic')
matplotlib.rcParams['figure.facecolor'] = 'w'

pd.set_option('display.max_rows', 250)
pd.set_option('display.max_columns', 250)
# pd.set_option('mode.chained_assignment', None)

# %%
print("Python version: {}".format(sys.version))
print("pandas version: {}".format(pd.__version__))
print("matplotlib version: {}".format(matplotlib.__version__))
print("NumPy version: {}".format(np.__version__))
print("SciPy version: {}".format(sp.__version__))
print("IPython version: {}".format(IPython.__version__))
print("scikit-learn version: {}".format(sk.__version__))
# Out:
# Python version: 3.7.9 (default, Aug 31 2020, 07:22:35)
# [Clang 10.0.0 ]
# pandas version: 1.1.3
# matplotlib version: 3.3.2
# NumPy version: 1.19.2
# SciPy version: 1.5.2
# IPython version: 7.19.0
# scikit-learn version: 0.23.2

# %% [markdown]
# ### List and set the working directory and the directory to write out data

# %%
# Topic of the Notebook which will also be the name of the subfolder containing results
TOPIC = 'fabian'

# Name of the external hard drive
DRIVE = 'GUSZTI'

# Directory containing clinical and blood gas data
CWD = '/Users/guszti/ventilation_fabian'

# Directory on external drive to read the ventilation data from
DIR_READ = '/Volumes/%s/Fabian/fabian_patient_data_all' % DRIVE

DIR_WRITE = '%s/%s' % (CWD, 'Analyses')

# Images and raw data will be written on an external hard drive
if not os.path.isdir('/Volumes/%s/data_dump/%s' % (DRIVE, TOPIC)):
    os.makedirs('/Volumes/%s/data_dump/%s' % (DRIVE, TOPIC))
DATA_DUMP = '/Volumes/%s/data_dump/%s' % (DRIVE, TOPIC)

# %%
os.chdir(CWD)
os.getcwd()
# Out:
# '/Users/guszti/ventilation_fabian'

# %%
DIR_READ, DIR_WRITE, DATA_DUMP
# Out:
# ('/Volumes/GUSZTI/Fabian/fabian_patient_data_all',
#  '/Users/guszti/ventilation_fabian/Analyses',
#  '/Volumes/GUSZTI/data_dump/fabian')

# %% [markdown]
# ### Import ventilation data
#
# This is needed to know the beginning and the end of the recordings

# %%
with open('%s/%s.pickle' % (DATA_DUMP, 'data_pars_1_150'), 'rb') as handle:
    data_pars_1_150 = pickle.load(handle)

with open('%s/%s.pickle' % (DATA_DUMP, 'data_pars_151_300'), 'rb') as handle:
    data_pars_151_300 = pickle.load(handle)
    
with open('%s/%s.pickle' % (DATA_DUMP, 'data_pars_301_450'), 'rb') as handle:
    data_pars_301_450 = pickle.load(handle)
    
with open('%s/%s.pickle' % (DATA_DUMP, 'data_pars_451_600'), 'rb') as handle:
    data_pars_451_600 = pickle.load(handle)
    
with open('%s/%s.pickle' % (DATA_DUMP, 'data_pars_601_750'), 'rb') as handle:
    data_pars_601_750 = pickle.load(handle)
    
with open('%s/%s.pickle' % (DATA_DUMP, 'data_pars_751_900'), 'rb') as handle:
    data_pars_751_900 = pickle.load(handle)
    
with open('%s/%s.pickle' % (DATA_DUMP, 'data_pars_901_1050'), 'rb') as handle:
    data_pars_901_1050 = pickle.load(handle)
    
with open('%s/%s.pickle' % (DATA_DUMP, 'data_pars_1051_1100'), 'rb') as handle:
    data_pars_1051_1100 = pickle.load(handle)
    
data_pars = {**data_pars_1_150, **data_pars_151_300, **data_pars_301_450,
             **data_pars_451_600, **data_pars_601_750, **data_pars_751_900,
             **data_pars_901_1050, **data_pars_1051_1100}

# %%
len(data_pars)
# Out:
# 874

# %% [markdown]
# ### Import clinical data

# %%
# import text files in a dictionary
clin_dict = {}
for fname in os.listdir(DIR_READ):
    if not fname.startswith('.'): # disregard hidden files
        fhandle = open(os.path.join('%s' % DIR_READ, fname), 'r', encoding = 'cp1252')
        clin_dict[fname[:-4]] = fhandle.read() # use the filenames without the .txt extension as keys
        fhandle.close()

# %%
# split the clinical data into a list
for key in sorted(clin_dict.keys()):
    clin_dict[key] = clin_dict[key].split('\n')[:-1]

# %%
# Create an inner dictionary for the different clinical data
for key, value in sorted(clin_dict.items()):
    temp_dict = {}
    for item in value:
        td_key, *td_value = item.split(':')
        td_key = td_key.strip()
        temp_dict[td_key] = ''.join(td_value)[1:]
    clin_dict[key] = temp_dict

# %%
# Create a DataFrame from the dictionary of dictionaries
clin_df = DataFrame(clin_dict).T
clin_df.index.name = 'Recording_ID'
clin_df.sort_index(inplace = True)

# %%
len(clin_df)
# Out:
# 925

# %% [markdown]
# ### Drop cases which have no clinical data

# %%
clin_df.dropna(axis = 0, how = 'all', inplace = True)

# %%
len(clin_df)
# Out:
# 850

# %%
writer = pd.ExcelWriter('%s/%s' % (DIR_WRITE, 'clinical_data_all_1_1100_unfiltered.xlsx'))
clin_df.to_excel(writer, 'clin_df')
writer.save()

# %% [markdown]
# ### Drop cases for which there is no ventilation data
#
# Ventilation recordings may have been excluded because they were two short (<15 mintes total) or aberrant

# %%
combined = sorted(set(list(clin_df.index)) & set(data_pars.keys()))

# %%
clin_df = clin_df.loc[combined]
len(clin_df)

# %% [markdown]
# ### Clean up clinical dataframe

# %%
# Curate the time of births of some recordings after manual inspection of case notes
clin_df.loc['AL000360']['Date of Birth'] = '20180906 0707'
clin_df.loc['AL000638']['Date of Birth'] = '20190814 1114'

# %%
# Change order of columns and create English names

clin_df = clin_df[['Esetlap id', 'Date of Birth', 'Gestation Age', 'Birth Weight', 
                   'Actual Weight', 'Pathology', 'Start', 'End']]
clin_df.columns = ['Case ID', 'Date of Birth', 'Gestational Age',
                   'Birth Weight', 'Actual Weight', 'Pathology', 'Start', 'End']

# %%
clin_df['Gestational Age'] = clin_df['Gestational Age'].map(lambda x: int(x[:2]))
clin_df['Birth Weight'] = clin_df['Birth Weight'].map(lambda x: int(x[:-6]))
clin_df['Actual Weight'] = clin_df['Actual Weight'].str.strip(' grams')
# Out:
# /Users/guszti/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /Users/guszti/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /Users/guszti/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
actual_weight = []
for i in range(len(clin_df)):
    if clin_df.iloc[i]['Actual Weight'] == '':
        actual_weight.append(clin_df.iloc[i]['Birth Weight'])
    else:
        actual_weight.append(int(clin_df.iloc[i]['Actual Weight']))

clin_df['Weight'] = actual_weight
# Out:
# /Users/guszti/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %% [markdown]
# #### Start and end from ventilation data
# This shows the time points when ventilator was turned on and off. At the beginning and the end of the recoridngs the baby was usually not attached to the ventilator. The ventilator recordings have been manually inspected and have been trimmed accordingly.

# %%
starts = {}; ends = {}
for rec in sorted(clin_df.index):
    try:
        starts[rec] = data_pars[rec].index[0]
    except KeyError:
        continue
        
    try:
        ends[rec] = data_pars[rec].index[-1]
    except KeyError:
        continue
        
start_end = DataFrame([starts, ends]).T
start_end.columns = ['Recording start', 'Recording end']

# %%
clin_df = pd.concat([clin_df, start_end], axis = 1, join = 'outer')

# %%
clin_df['Date of Birth'] = clin_df['Date of Birth'].map(lambda x: pd.to_datetime(x))
clin_df['Pathology'] = clin_df['Pathology'].map(lambda x: x.split(';')[:-1])

# %%
clin_df['Duration'] = clin_df['Recording end'] - clin_df['Recording start']

# %%
clin_df['Postnatal Age']   = clin_df['Recording end'] - clin_df['Date of Birth']

# %%
clin_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 850 entries, AL000003 to AL001099
# Data columns (total 13 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Case ID          850 non-null    object
#  1   Date of Birth    850 non-null    datetime64[ns]
#  2   Gestational Age  850 non-null    int64
#  3   Birth Weight     850 non-null    int64
#  4   Actual Weight    850 non-null    object
#  5   Pathology        850 non-null    object
#  6   Start            850 non-null    object
#  7   End              850 non-null    object
#  8   Weight           850 non-null    int64
#  9   Recording start  792 non-null    datetime64[ns]
#  10  Recording end    792 non-null    datetime64[ns]
#  11  Duration         792 non-null    timedelta64[ns]
#  12  Postnatal Age    792 non-null    timedelta64[ns]
# dtypes: datetime64[ns](3), int64(3), object(5), timedelta64[ns](2)
# memory usage: 93.0+ KB

# %%
clin_df['Gestational Age'] = pd.to_timedelta((clin_df['Gestational Age']), unit='W', errors='raise')

# %%
clin_df['Corrected gestational Age'] = pd.to_timedelta((clin_df['Gestational Age']), unit='D', 
                                                       errors='raise') + clin_df['Postnatal Age']

# %%
clin_df['Gestational Age (weeks)'] = \
    clin_df['Gestational Age'].apply(lambda x: x.total_seconds() / (60 * 60 * 24 * 7))

clin_df['Corrected gestational Age (weeks)'] = \
    clin_df['Corrected gestational Age'].apply(lambda x: round(x.total_seconds() / (60 * 60 * 24 * 7), 1))

# %%
clin_df.sort_index(axis = 1).head()
# Out:
#          Actual Weight  Birth Weight Case ID Corrected gestational Age  \
# AL000003                         990   42543         196 days 02:09:04
# AL000005                        3530   42552         259 days 02:07:19
# AL000006                        1470   42554         217 days 01:18:07
# AL000007          4800          3200   42578         339 days 02:48:57
# AL000008                        3230   42596         266 days 04:22:48
#
#           Corrected gestational Age (weeks)       Date of Birth  \
# AL000003                               28.0 2017-03-24 17:41:00
# AL000005                               37.0 2017-03-26 17:50:00
# AL000006                               31.0 2017-03-26 23:37:00
# AL000007                               48.4 2017-01-29 00:00:00
# AL000008                               38.0 2017-03-29 13:20:00
#
#                 Duration                            End Gestational Age  \
# AL000003 0 days 01:44:57  Fri, 24 Mar 2017 195004 +0100        196 days
# AL000005 0 days 00:42:26  Sun, 26 Mar 2017 195719 +0200        259 days
# AL000006 0 days 00:50:46  Mon, 27 Mar 2017 005507 +0200        217 days
# AL000007 0 days 02:00:28  Wed, 29 Mar 2017 024857 +0200        280 days
# AL000008 0 days 01:58:22  Wed, 29 Mar 2017 174248 +0200        266 days
#
#           Gestational Age (weeks)  \
# AL000003                     28.0
# AL000005                     37.0
# AL000006                     31.0
# AL000007                     40.0
# AL000008                     38.0
#
#                                                   Pathology    Postnatal Age  \
# AL000003  [Neonat praemat gr s 28 (P07.3)  ,  IRDS (P22....  0 days 02:09:04
# AL000005  [Neonat mat gr s 37 (P96.4)  ,  Infectio (P39....  0 days 02:07:19
# AL000006  [Neonat praemat gr s 31 (P07.3)  ,  Gemini A (...  0 days 01:18:07
# AL000007  [Exsiccatio (E86)  ,  Légzési elégtelenség (P2... 59 days 02:48:57
# AL000008  [Neonat mat gr s 38 (P96.4)  ,  Intézeten kívü...  0 days 04:22:48
#
#                Recording end     Recording start  \
# AL000003 2017-03-24 19:50:04 2017-03-24 18:05:07
# AL000005 2017-03-26 19:57:19 2017-03-26 19:14:53
# AL000006 2017-03-27 00:55:07 2017-03-27 00:04:21
# AL000007 2017-03-29 02:48:57 2017-03-29 00:48:29
# AL000008 2017-03-29 17:42:48 2017-03-29 15:44:26
#
#                                   Start  Weight
# AL000003  Fri, 24 Mar 2017 180507 +0100     990
# AL000005  Sun, 26 Mar 2017 191453 +0200    3530
# AL000006  Mon, 27 Mar 2017 000421 +0200    1470
# AL000007  Wed, 29 Mar 2017 004829 +0200    4800
# AL000008  Wed, 29 Mar 2017 154426 +0200    3230

# %% [markdown]
# ### EDA on clinical details

# %%
clin_df.describe()
# Out:
#                    Gestational Age  Birth Weight       Weight  \
# count                          850    850.000000   850.000000
# mean   242 days 18:49:58.588235296   2435.655294  2609.732941
# std     33 days 22:12:49.083953691   1021.366885  1032.950271
# min              147 days 00:00:00    300.000000   300.000000
# 25%              224 days 00:00:00   1692.500000  1850.000000
# 50%              252 days 00:00:00   2600.000000  2715.000000
# 75%              266 days 00:00:00   3200.000000  3347.500000
# max              294 days 00:00:00   5400.000000  5920.000000
#
#                         Duration               Postnatal Age  \
# count                        792                         792
# mean   0 days 01:17:24.023989898  12 days 19:41:55.128787878
# std    0 days 00:54:51.966850579  30 days 19:50:27.660454673
# min              0 days 00:16:08             0 days 00:01:09
# 25%       0 days 00:46:45.750000      0 days 03:07:50.250000
# 50%              0 days 01:07:44             0 days 06:57:55
# 75%              0 days 01:38:41             5 days 18:09:21
# max              0 days 19:03:15           231 days 10:33:32
#
#          Corrected gestational Age  Gestational Age (weeks)  \
# count                          792               850.000000
# mean   255 days 21:52:49.674242444                34.683529
# std     41 days 09:38:00.784496699                 4.846510
# min              147 days 01:41:03                21.000000
# 25%       231 days 10:18:43.250000                32.000000
# 50%              259 days 02:24:49                36.000000
# 75%       274 days 05:09:33.750000                38.000000
# max              503 days 13:40:44                42.000000
#
#        Corrected gestational Age (weeks)
# count                         792.000000
# mean                           36.546970
# std                             5.915318
# min                            21.000000
# 25%                            33.100000
# 50%                            37.000000
# 75%                            39.200000
# max                            71.900000

# %% [markdown]
# #### For some recordings the age at the time of transfer is "negative"  - these need to be corrected

# %%
clin_df[clin_df['Postnatal Age'] < pd.to_timedelta(0)]
# Out:
# Empty DataFrame
# Columns: [Case ID, Date of Birth, Gestational Age, Birth Weight, Actual Weight, Pathology, Start, End, Weight, Recording start, Recording end, Duration, Postnatal Age, Corrected gestational Age, Gestational Age (weeks), Corrected gestational Age (weeks)]
# Index: []

# %% [markdown]
# #### For some recordings the duration of the recording is "negative"  - these need to be corrected

# %%
clin_df[clin_df['Duration'] < pd.to_timedelta(0)]
# Out:
# Empty DataFrame
# Columns: [Case ID, Date of Birth, Gestational Age, Birth Weight, Actual Weight, Pathology, Start, End, Weight, Recording start, Recording end, Duration, Postnatal Age, Corrected gestational Age, Gestational Age (weeks), Corrected gestational Age (weeks)]
# Index: []

# %% [markdown]
# #### Babies was at less than 23 weeks gestation

# %%
clin_df[clin_df['Gestational Age (weeks)'] < 23]
# Out:
#          Case ID       Date of Birth Gestational Age  Birth Weight  \
# AL000294   47588 2018-07-10 11:30:00        147 days           300
# AL000561   50979 2019-06-01 22:08:00        154 days           580
#
#          Actual Weight                                          Pathology  \
# AL000294                [Neonat immat gr s 21 (P07.2)  ,  Resuscitatio...
# AL000561                [Neonat immat gr s 22 (P07.2)  ,  Gemini A (P0...
#
#                                   Start                            End  \
# AL000294  Tue, 10 Jul 2018 122935 +0200  Tue, 10 Jul 2018 131103 +0200
# AL000561  Sat, 01 Jun 2019 224754 +0200  Sun, 02 Jun 2019 011426 +0200
#
#           Weight     Recording start       Recording end        Duration  \
# AL000294     300 2018-07-10 12:29:35 2018-07-10 13:11:03 0 days 00:41:28
# AL000561     580 2019-06-01 22:47:54 2019-06-02 01:14:26 0 days 02:26:32
#
#            Postnatal Age Corrected gestational Age  Gestational Age (weeks)  \
# AL000294 0 days 01:41:03         147 days 01:41:03                     21.0
# AL000561 0 days 03:06:26         154 days 03:06:26                     22.0
#
#           Corrected gestational Age (weeks)
# AL000294                               21.0
# AL000561                               22.0

# %% [markdown]
# #### Babies born with less than 500 g birth weight

# %%
clin_df[clin_df['Birth Weight'] < 500]
# Out:
#          Case ID       Date of Birth Gestational Age  Birth Weight  \
# AL000038   42889 2017-04-01 00:00:00        161 days           490
# AL000066   43365 2017-05-18 14:24:00        168 days           450
# AL000099   43778 2017-06-10 10:44:00        182 days           490
# AL000100   43779 2017-04-01 00:00:00        175 days           490
# AL000101   43781 2017-04-01 00:00:00        175 days           490
# AL000140   44200 2017-08-08 10:20:00        161 days           410
# AL000163   45238 2017-07-13 18:07:00        168 days           360
# AL000182   45454 2017-07-13 23:05:00        168 days           360
# AL000294   47588 2018-07-10 11:30:00        147 days           300
# AL000348   48173 2018-07-27 00:00:00        175 days           490
# AL000465   50028 2019-02-23 05:48:00        161 days           400
# AL000642   51874 2019-05-16 15:13:00        189 days           460
# AL000683   52183 2019-09-16 00:00:00        161 days           490
#
#          Actual Weight                                          Pathology  \
# AL000038           690  [Neonat immat gr s 22 (P07.2) 22-23 ,  Ileus (...
# AL000066           650  [PDA (Q25.0)  ,  Neonat immat gr s 24 (P07.2) ...
# AL000099           830  [Neonat immat gr s 26 (P07.2)  ,  NEC (P77)  ,...
# AL000100          1890                    [ROP (H35.1)  ,  BPD (P27.1)  ]
# AL000101          1890  [ROP (H35.1) st.p. vitrectomian l.u. ,  BPD (P...
# AL000140           640  [Neonat immat gr s 23 (P07.2)  ,  NEC (P77)  ,...
# AL000163          2880  [BPD (P27.1)  ,  Légzési elégtelenség (P28.5) ...
# AL000182          3300  [Neonat immat gr s 24 (P07.2)  ,  Hernia ingui...
# AL000294                [Neonat immat gr s 21 (P07.2)  ,  Resuscitatio...
# AL000348                [Neonat immat gr s 25 (P07.2)  ,  Hypothermia ...
# AL000465                [RDS (P22)  ,  Hypothermia (P80.9)  ,  Neonat ...
# AL000642          1890  [NEC (P77)  ,  BPD (P27.1)  ,  Septicus shock ...
# AL000683                [RDS (P22)  ,  Infectio (P39.9)  ,  Neonat imm...
#
#                                   Start                            End  \
# AL000038  Sat, 29 Apr 2017 091252 +0200  Sat, 29 Apr 2017 105944 +0200
# AL000066  Wed, 14 Jun 2017 105336 +0200  Wed, 14 Jun 2017 121541 +0200
# AL000099  Sun, 23 Jul 2017 151033 +0200  Sun, 23 Jul 2017 155506 +0200
# AL000100  Mon, 24 Jul 2017 083540 +0200  Mon, 24 Jul 2017 091856 +0200
# AL000101  Mon, 24 Jul 2017 110810 +0200  Mon, 24 Jul 2017 114954 +0200
# AL000140  Fri, 25 Aug 2017 132348 +0200  Fri, 25 Aug 2017 151422 +0200
# AL000163  Sat, 25 Nov 2017 144108 +0100  Sat, 25 Nov 2017 164239 +0100
# AL000182  Wed, 13 Dec 2017 124334 +0100  Wed, 13 Dec 2017 144535 +0100
# AL000294  Tue, 10 Jul 2018 122935 +0200  Tue, 10 Jul 2018 131103 +0200
# AL000348  Tue, 28 Aug 2018 153653 +0200  Tue, 28 Aug 2018 162146 +0200
# AL000465  Sat, 23 Feb 2019 071223 +0100  Sat, 23 Feb 2019 082653 +0100
# AL000642  Sat, 17 Aug 2019 153638 +0200  Sat, 17 Aug 2019 162418 +0200
# AL000683  Mon, 16 Sep 2019 081829 +0200  Mon, 16 Sep 2019 092403 +0200
#
#           Weight     Recording start       Recording end        Duration  \
# AL000038     690 2017-04-29 09:12:52 2017-04-29 10:59:44 0 days 01:46:52
# AL000066     650 2017-06-14 10:53:36 2017-06-14 12:15:41 0 days 01:22:05
# AL000099     830 2017-07-23 15:10:33 2017-07-23 15:55:06 0 days 00:44:33
# AL000100    1890 2017-07-24 08:35:40 2017-07-24 09:18:56 0 days 00:43:16
# AL000101    1890 2017-07-24 11:08:10 2017-07-24 11:49:54 0 days 00:41:44
# AL000140     640 2017-08-25 13:23:48 2017-08-25 15:14:22 0 days 01:50:34
# AL000163    2880 2017-11-25 14:41:08 2017-11-25 16:42:39 0 days 02:01:31
# AL000182    3300 2017-12-13 12:43:34 2017-12-13 14:45:35 0 days 02:02:01
# AL000294     300 2018-07-10 12:29:35 2018-07-10 13:11:03 0 days 00:41:28
# AL000348     490 2018-08-28 15:36:53 2018-08-28 16:21:46 0 days 00:44:53
# AL000465     400 2019-02-23 07:12:23 2019-02-23 08:26:53 0 days 01:14:30
# AL000642    1890 2019-08-17 15:36:38 2019-08-17 16:24:18 0 days 00:47:40
# AL000683     490 2019-09-16 08:18:29 2019-09-16 09:24:03 0 days 01:05:34
#
#              Postnatal Age Corrected gestational Age  Gestational Age (weeks)  \
# AL000038  28 days 10:59:44         189 days 10:59:44                     23.0
# AL000066  26 days 21:51:41         194 days 21:51:41                     24.0
# AL000099  43 days 05:11:06         225 days 05:11:06                     26.0
# AL000100 114 days 09:18:56         289 days 09:18:56                     25.0
# AL000101 114 days 11:49:54         289 days 11:49:54                     25.0
# AL000140  17 days 04:54:22         178 days 04:54:22                     23.0
# AL000163 134 days 22:35:39         302 days 22:35:39                     24.0
# AL000182 152 days 15:40:35         320 days 15:40:35                     24.0
# AL000294   0 days 01:41:03         147 days 01:41:03                     21.0
# AL000348  32 days 16:21:46         207 days 16:21:46                     25.0
# AL000465   0 days 02:38:53         161 days 02:38:53                     23.0
# AL000642  93 days 01:11:18         282 days 01:11:18                     27.0
# AL000683   0 days 09:24:03         161 days 09:24:03                     23.0
#
#           Corrected gestational Age (weeks)
# AL000038                               27.1
# AL000066                               27.8
# AL000099                               32.2
# AL000100                               41.3
# AL000101                               41.4
# AL000140                               25.5
# AL000163                               43.3
# AL000182                               45.8
# AL000294                               21.0
# AL000348                               29.7
# AL000465                               23.0
# AL000642                               40.3
# AL000683                               23.1

# %%
len(clin_df[clin_df['Birth Weight'] < 500])
# Out:
# 13

# %% [markdown]
# #### Babies transferred with the postnatal age of > 46 weeks we need to discuss whether to include them in the data analysis

# %%
a = clin_df[clin_df['Corrected gestational Age (weeks)'] > 46]
a.sort_values('Corrected gestational Age (weeks)')
# Out:
#          Case ID       Date of Birth Gestational Age  Birth Weight  \
# AL000451   49876 2019-01-02 00:00:00        287 days          3000
# AL000782   53788 2019-12-15 10:07:00        266 days          4020
# AL000823   54127 2020-01-14 00:00:00        266 days          3580
# AL000459   49912 2019-01-02 00:00:00        287 days          3000
# AL000688   52223 2019-07-07 09:05:00        259 days          2265
# AL000819   54105 2019-10-14 00:00:00        182 days           950
# AL000042   42922 2017-02-23 00:00:00        266 days          3000
# AL000043   42923 2017-02-23 00:00:00        266 days          3000
# AL000478   50349 2019-02-01 00:00:00        280 days          3550
# AL000690   52261 2019-07-07 09:05:00        259 days          2265
# AL000206   46297 2018-01-10 00:00:00        280 days          3900
# AL000174   45384 2017-09-27 11:01:00        266 days          3580
# AL000007   42578 2017-01-29 00:00:00        280 days          3200
# AL000471   50055 2019-01-02 00:00:00        287 days          3000
# AL000283   47431 2018-02-14 00:00:00        210 days           900
# AL000968   54897 2020-04-08 12:11:00        266 days          1920
# AL000606   51350 2019-04-11 20:50:00        273 days          3370
# AL000715   53142 2019-08-28 00:00:00        252 days          2970
# AL000026   42817 2017-01-13 00:00:00        266 days          2940
# AL000028   42827 2017-01-13 00:00:00        266 days          2940
# AL000035   42871 2016-12-13 00:00:00        231 days          1940
# AL000037   42882 2016-12-13 00:00:00        231 days          1940
# AL000761   53645 2019-10-24 08:35:00        273 days          2320
# AL000033   42863 2017-01-13 00:00:00        266 days          2940
# AL000047   42975 2016-12-13 09:10:00        224 days          2000
# AL000464   49946 2018-10-10 00:21:00        245 days          2450
# AL000114   43929 2017-02-25 00:00:00        217 days           990
# AL000579   51113 2019-01-31 00:00:00        252 days          1490
# AL000581   51144 2019-01-31 00:00:00        252 days          1490
# AL000747   53488 2019-09-27 00:00:00        280 days          2990
# AL000379   48822 2018-06-29 00:00:00        273 days          3100
# AL000261   47213 2018-02-19 00:00:00        294 days          3000
# AL000818   54071 2019-10-24 08:35:00        273 days          2320
# AL000627   51727 2019-01-31 00:00:00        252 days          1490
# AL001010   55136 2020-01-06 00:00:00        259 days          2400
# AL000689   52229 2019-01-31 00:00:00        252 days          1490
# AL000934   54712 2019-10-24 00:00:00        273 days          2320
#
#          Actual Weight                                          Pathology  \
# AL000451          3720  [Stenosis tracheae (Q32.1)  ,  Infectio (P39.9...
# AL000782          4230  [Neonat mat gr s 38 (P96.4)  ,  Vitium cordis ...
# AL000823                [Neonat mat gr s 38 (P96.4)  ,  ASD (Q21.1)  ,...
# AL000459          3720  [Foramen ovale apertum (Q21.1)  ,  Stenosis tr...
# AL000688          4245  [Neonat mat gr s 37 (P96.4)  ,  Postasphyxias ...
# AL000819          3250  [Pneumonia (J18.9)  ,  Légzési elégtelenség (P...
# AL000042          4900  [Neonat mat gr s 39 (P96.4)  ,  Convulsio (P90...
# AL000043          4900  [Neonat mat gr s 38 (P96.4)  ,  Convulsio (P90...
# AL000478          4310  [Hypotonia musculorum (P94.2)  ,  Légzészavar ...
# AL000690          4200  [Encephalopathia (G93.4) postasphyxias ,  Gast...
# AL000206                [Pulmonalis atresia (Q22.0) st.p. palliationem...
# AL000174          4200  [Hydrocephalus (G91.9) Arnold Chiari malformat...
# AL000007          4800  [Exsiccatio (E86)  ,  Légzési elégtelenség (P2...
# AL000471          4070                      [Stenosis tracheae (Q32.1)  ]
# AL000283          2600  [Légzési elégtelenség (P28.5)  ,  Convulsio (P...
# AL000968          3800  [Balszívfél hypoplasia (Q23.4) Di George-sy , ...
# AL000606          3890  [Truncus arteriosus communis (Q21.2) st.p.op. ...
# AL000715          4200  [Vitium cordis cong (Q20.5) st.p. palliationen...
# AL000026          3600  [Neonat mat gr s 38 (P96.4)  ,  Dextrocardia (...
# AL000028          4010  [Légzési elégtelenség (P28.5)  ,  Infectio (P3...
# AL000035          4460  [Pulmonalis hypertonia (I27.0)  ,  BPD (P27.1)...
# AL000037          4460  [Vitium cordis cong (Q20.5)  ,  Decompensatio ...
# AL000761          3350  [VACTERL associatio (Q87.2)  ,  ASD (Q21.1)  ,...
# AL000033          4020  [Decompensatio cardialis (I50.0)  ,  Vitium co...
# AL000047          4215  [Légzészavar (P22.8)  ,  Neonat praemat gr s 3...
# AL000464          3930  [Infectio (P39.9) RSV ,  Tricuspidalis atraesi...
# AL000114          2920  [Fallot tetralogia (Q21.3)  ,  A belek egyéb m...
# AL000579          3500  [Down syndroma (Q90.0)  ,  AV canal (Q21.2)  ,...
# AL000581          3100  [Down syndroma (Q90.0)  ,  Légzési elégtelensé...
# AL000747          4200  [Aorta stenosis (Q25.3) st.p.op. ,  Pulmonalis...
# AL000379          5700  [Bronchitis obstructiva (J20.9)  ,  Bronchioli...
# AL000261          5600  [Decompensatio cardialis (I50.0)  ,  Mitralis ...
# AL000818          3500  [VACTERL associatio (Q87.2)  ,  Légzési elégte...
# AL000627          3845  [Down syndroma (Q90.0)  ,  AV canal (Q21.2) St...
# AL001010          5920  [Neonat mat gr s 37 (P96.4)  ,  Epilepsia (G40...
# AL000689          4790  [Down syndroma (Q90.0)  ,  Tracheostomával élõ...
# AL000934          5250  [Neonat mat gr s 38 (P96.4)  ,  Atresia coli (...
#
#                                   Start                            End  \
# AL000451  Thu, 07 Feb 2019 063812 +0100  Thu, 07 Feb 2019 070516 +0100
# AL000782  Tue, 11 Feb 2020 102153 +0100  Tue, 11 Feb 2020 113111 +0100
# AL000823  Fri, 13 Mar 2020 155505 +0100  Fri, 13 Mar 2020 171936 +0100
# AL000459  Mon, 11 Feb 2019 120638 +0100  Mon, 11 Feb 2019 124448 +0100
# AL000688  Wed, 18 Sep 2019 090008 +0200  Wed, 18 Sep 2019 092730 +0200
# AL000819  Thu, 12 Mar 2020 103614 +0100  Thu, 12 Mar 2020 112302 +0100
# AL000042  Tue, 02 May 2017 193707 +0200  Tue, 02 May 2017 202154 +0200
# AL000043  Tue, 02 May 2017 204804 +0200  Tue, 02 May 2017 211132 +0200
# AL000478  Wed, 27 Mar 2019 123644 +0100  Wed, 27 Mar 2019 131024 +0100
# AL000690  Sun, 22 Sep 2019 051336 +0200  Sun, 22 Sep 2019 063040 +0200
# AL000206  Wed, 07 Mar 2018 135008 +0100  Wed, 07 Mar 2018 150529 +0100
# AL000174  Fri, 08 Dec 2017 103722 +0100  Fri, 08 Dec 2017 112934 +0100
# AL000007  Wed, 29 Mar 2017 004829 +0200  Wed, 29 Mar 2017 024857 +0200
# AL000471  Tue, 26 Feb 2019 084759 +0100  Tue, 26 Feb 2019 101541 +0100
# AL000283  Tue, 26 Jun 2018 085207 +0200  Tue, 26 Jun 2018 110554 +0200
# AL000968  Thu, 02 Jul 2020 143031 +0200  Thu, 02 Jul 2020 144947 +0200
# AL000606  Tue, 02 Jul 2019 143700 +0200  Tue, 02 Jul 2019 173021 +0200
# AL000715  Sat, 14 Dec 2019 102224 +0100  Sat, 14 Dec 2019 105924 +0100
# AL000026  Thu, 20 Apr 2017 120810 +0200  Thu, 20 Apr 2017 153844 +0200
# AL000028  Fri, 21 Apr 2017 124947 +0200  Fri, 21 Apr 2017 142217 +0200
# AL000035  Thu, 27 Apr 2017 085948 +0200  Thu, 27 Apr 2017 094210 +0200
# AL000037  Fri, 28 Apr 2017 115106 +0200  Fri, 28 Apr 2017 122522 +0200
# AL000761  Tue, 28 Jan 2020 122529 +0100  Tue, 28 Jan 2020 134559 +0100
# AL000033  Wed, 26 Apr 2017 093059 +0200  Wed, 26 Apr 2017 102855 +0200
# AL000047  Mon, 08 May 2017 172704 +0200  Mon, 08 May 2017 180549 +0200
# AL000464  Thu, 14 Feb 2019 103124 +0100  Thu, 14 Feb 2019 113050 +0100
# AL000114  Thu, 03 Aug 2017 090050 +0200  Thu, 03 Aug 2017 105242 +0200
# AL000579  Wed, 12 Jun 2019 102959 +0200  Wed, 12 Jun 2019 130317 +0200
# AL000581  Fri, 14 Jun 2019 093848 +0200  Fri, 14 Jun 2019 112704 +0200
# AL000747  Tue, 14 Jan 2020 095844 +0100  Tue, 14 Jan 2020 114508 +0100
# AL000379  Sat, 03 Nov 2018 090244 +0100  Sat, 03 Nov 2018 103112 +0100
# AL000261  Wed, 06 Jun 2018 102258 +0200  Wed, 06 Jun 2018 105810 +0200
# AL000818  Mon, 09 Mar 2020 130201 +0100  Mon, 09 Mar 2020 134409 +0100
# AL000627  Mon, 05 Aug 2019 110319 +0200  Mon, 05 Aug 2019 125613 +0200
# AL001010  Tue, 28 Jul 2020 131604 +0200  Tue, 28 Jul 2020 143626 +0200
# AL000689  Thu, 19 Sep 2019 084834 +0200  Thu, 19 Sep 2019 103332 +0200
# AL000934  Wed, 10 Jun 2020 120707 +0200  Wed, 10 Jun 2020 134044 +0200
#
#           Weight     Recording start       Recording end        Duration  \
# AL000451    3720 2019-02-07 06:38:12 2019-02-07 07:05:16 0 days 00:27:04
# AL000782    4230 2020-02-11 10:21:53 2020-02-11 11:31:11 0 days 01:09:18
# AL000823    3580 2020-03-13 15:55:05 2020-03-13 17:19:36 0 days 01:24:31
# AL000459    3720 2019-02-11 12:06:38 2019-02-11 12:44:48 0 days 00:38:10
# AL000688    4245 2019-09-18 09:00:08 2019-09-18 09:27:30 0 days 00:27:22
# AL000819    3250 2020-03-12 10:36:14 2020-03-12 11:23:02 0 days 00:46:48
# AL000042    4900 2017-05-02 19:37:07 2017-05-02 20:21:54 0 days 00:44:47
# AL000043    4900 2017-05-02 20:48:04 2017-05-02 21:11:32 0 days 00:23:28
# AL000478    4310 2019-03-27 12:36:44 2019-03-27 13:10:24 0 days 00:33:40
# AL000690    4200 2019-09-22 05:13:36 2019-09-22 06:30:40 0 days 01:17:04
# AL000206    3900 2018-03-07 13:50:08 2018-03-07 15:05:29 0 days 01:15:21
# AL000174    4200 2017-12-08 10:37:22 2017-12-08 11:29:34 0 days 00:52:12
# AL000007    4800 2017-03-29 00:48:29 2017-03-29 02:48:57 0 days 02:00:28
# AL000471    4070 2019-02-26 08:47:59 2019-02-26 10:15:41 0 days 01:27:42
# AL000283    2600 2018-06-26 08:52:07 2018-06-26 11:05:54 0 days 02:13:47
# AL000968    3800 2020-07-02 14:30:31 2020-07-02 14:49:47 0 days 00:19:16
# AL000606    3890 2019-07-02 14:37:00 2019-07-02 17:30:21 0 days 02:53:21
# AL000715    4200 2019-12-14 10:22:24 2019-12-14 10:59:24 0 days 00:37:00
# AL000026    3600 2017-04-20 12:08:10 2017-04-20 15:38:44 0 days 03:30:34
# AL000028    4010 2017-04-21 12:49:47 2017-04-21 14:22:17 0 days 01:32:30
# AL000035    4460 2017-04-27 08:59:48 2017-04-27 09:42:10 0 days 00:42:22
# AL000037    4460 2017-04-28 11:51:06 2017-04-28 12:25:22 0 days 00:34:16
# AL000761    3350 2020-01-28 12:25:29 2020-01-28 13:45:59 0 days 01:20:30
# AL000033    4020 2017-04-26 09:30:59 2017-04-26 10:28:55 0 days 00:57:56
# AL000047    4215 2017-05-08 17:27:04 2017-05-08 18:05:49 0 days 00:38:45
# AL000464    3930 2019-02-14 10:31:24 2019-02-14 11:30:50 0 days 00:59:26
# AL000114    2920 2017-08-03 09:00:50 2017-08-03 10:52:42 0 days 01:51:52
# AL000579    3500 2019-06-12 10:29:59 2019-06-12 13:03:17 0 days 02:33:18
# AL000581    3100 2019-06-14 09:38:48 2019-06-14 11:27:04 0 days 01:48:16
# AL000747    4200 2020-01-14 09:58:44 2020-01-14 11:45:08 0 days 01:46:24
# AL000379    5700 2018-11-03 09:02:44 2018-11-03 10:31:12 0 days 01:28:28
# AL000261    5600 2018-06-06 10:22:58 2018-06-06 10:58:10 0 days 00:35:12
# AL000818    3500 2020-03-09 13:02:01 2020-03-09 13:44:09 0 days 00:42:08
# AL000627    3845 2019-08-05 11:03:19 2019-08-05 12:56:13 0 days 01:52:54
# AL001010    5920 2020-07-28 13:16:04 2020-07-28 14:36:26 0 days 01:20:22
# AL000689    4790 2019-09-19 08:48:34 2019-09-19 10:33:32 0 days 01:44:58
# AL000934    5250 2020-06-10 12:07:07 2020-06-10 13:40:44 0 days 01:33:37
#
#              Postnatal Age Corrected gestational Age  Gestational Age (weeks)  \
# AL000451  36 days 07:05:16         323 days 07:05:16                     41.0
# AL000782  58 days 01:24:11         324 days 01:24:11                     38.0
# AL000823  59 days 17:19:36         325 days 17:19:36                     38.0
# AL000459  40 days 12:44:48         327 days 12:44:48                     41.0
# AL000688  73 days 00:22:30         332 days 00:22:30                     37.0
# AL000819 150 days 11:23:02         332 days 11:23:02                     26.0
# AL000042  68 days 20:21:54         334 days 20:21:54                     38.0
# AL000043  68 days 21:11:32         334 days 21:11:32                     38.0
# AL000478  54 days 13:10:24         334 days 13:10:24                     40.0
# AL000690  76 days 21:25:40         335 days 21:25:40                     37.0
# AL000206  56 days 15:05:29         336 days 15:05:29                     40.0
# AL000174  72 days 00:28:34         338 days 00:28:34                     38.0
# AL000007  59 days 02:48:57         339 days 02:48:57                     40.0
# AL000471  55 days 10:15:41         342 days 10:15:41                     41.0
# AL000283 132 days 11:05:54         342 days 11:05:54                     30.0
# AL000968  85 days 02:38:47         351 days 02:38:47                     38.0
# AL000606  81 days 20:40:21         354 days 20:40:21                     39.0
# AL000715 108 days 10:59:24         360 days 10:59:24                     36.0
# AL000026  97 days 15:38:44         363 days 15:38:44                     38.0
# AL000028  98 days 14:22:17         364 days 14:22:17                     38.0
# AL000035 135 days 09:42:10         366 days 09:42:10                     33.0
# AL000037 136 days 12:25:22         367 days 12:25:22                     33.0
# AL000761  96 days 05:10:59         369 days 05:10:59                     39.0
# AL000033 103 days 10:28:55         369 days 10:28:55                     38.0
# AL000047 146 days 08:55:49         370 days 08:55:49                     32.0
# AL000464 127 days 11:09:50         372 days 11:09:50                     35.0
# AL000114 159 days 10:52:42         376 days 10:52:42                     31.0
# AL000579 132 days 13:03:17         384 days 13:03:17                     36.0
# AL000581 134 days 11:27:04         386 days 11:27:04                     36.0
# AL000747 109 days 11:45:08         389 days 11:45:08                     40.0
# AL000379 127 days 10:31:12         400 days 10:31:12                     39.0
# AL000261 107 days 10:58:10         401 days 10:58:10                     42.0
# AL000818 137 days 05:09:09         410 days 05:09:09                     39.0
# AL000627 186 days 12:56:13         438 days 12:56:13                     36.0
# AL001010 204 days 14:36:26         463 days 14:36:26                     37.0
# AL000689 231 days 10:33:32         483 days 10:33:32                     36.0
# AL000934 230 days 13:40:44         503 days 13:40:44                     39.0
#
#           Corrected gestational Age (weeks)
# AL000451                               46.2
# AL000782                               46.3
# AL000823                               46.5
# AL000459                               46.8
# AL000688                               47.4
# AL000819                               47.5
# AL000042                               47.8
# AL000043                               47.8
# AL000478                               47.8
# AL000690                               48.0
# AL000206                               48.1
# AL000174                               48.3
# AL000007                               48.4
# AL000471                               48.9
# AL000283                               48.9
# AL000968                               50.2
# AL000606                               50.7
# AL000715                               51.5
# AL000026                               52.0
# AL000028                               52.1
# AL000035                               52.3
# AL000037                               52.5
# AL000761                               52.7
# AL000033                               52.8
# AL000047                               52.9
# AL000464                               53.2
# AL000114                               53.8
# AL000579                               54.9
# AL000581                               55.2
# AL000747                               55.6
# AL000379                               57.2
# AL000261                               57.4
# AL000818                               58.6
# AL000627                               62.6
# AL001010                               66.2
# AL000689                               69.1
# AL000934                               71.9

# %%
len(clin_df[clin_df['Corrected gestational Age (weeks)'] > 46])
# Out:
# 37

# %% [markdown]
# ### Identify ICD codes

# %%
icd = re.compile(r'\(\S\d+\.?\d*\)')

# %%
def icd_finder(lst):
    icd_list = []
    for item in lst:
        if icd.findall(item):
            icd_list.append(icd.findall(item)[0])
    
    return icd_list

# %%
def icd_cleanup(lst):
    icd_list = []
    for item in lst:
        if '.' in item:
            new_item = item[0 : item.index('.')] + item[item.index('.') + 1 : ]
        else:
            new_item = item
        icd_list.append(new_item[1:-1])
    return icd_list

# %%
clin_df['ICD'] = clin_df['Pathology'].apply(icd_finder)

# %%
clin_df['ICD'] = clin_df['ICD'].apply(icd_cleanup)

# %%
clin_df['ICD'];

# %% [markdown]
# ### Identify all icd codes

# %%
icd_all = []

for _, item in clin_df.iterrows():
    icd_all.extend(item['ICD'])
    
icd_all = sorted(set(icd_all))

# %%
len(icd_all)
# Out:
# 195

# %%
icd_all_frme = DataFrame(icd_all)
icd_all_frme.columns = ['code']
icd_all_frme.sort_values(by = 'code', inplace = True)

# %%
icd_all_frme.head()
# Out:
#     code
# 0   A419
# 1   D180
# 2   D181
# 3   D379
# 4  D4890

# %%
len(icd_all_frme)
# Out:
# 195

# %%
writer = pd.ExcelWriter('%s/%s' % (DIR_WRITE, 'icd_codes.xlsx'))
icd_all_frme.to_excel(writer, 'icd_codes')
writer.save()

# %% [markdown]
# ### Import the file that has been manually curated from the exported `icd_codes.xlsx` files to contain all relevant diagnosis previously identified

# %%
icd_codes = pd.read_excel('/Users/guszti/ventilation_fabian/icd_codes_curated.xlsx', 
                          usecols = [0,1], index_col = 0)

# %%
icd_codes.head()
# Out:
#                                                     name
# code
# A419                        Sepsis, unspecified organism
# D180                         Hemangioma unspecified site
# D181                              Lymphangioma, any site
# D379   Neoplasm of uncertain behavior of digestive or...
# D4890        Neoplasm of uncertain behavior, unspecified

# %%
icd_all_frme.head()
# Out:
#     code
# 0   A419
# 1   D180
# 2   D181
# 3   D379
# 4  D4890

# %% [markdown]
# Identify new codes not in the dataset so far

# %%
new_diagnoses = sorted(set(icd_all_frme['code']) - set(icd_codes.index))
new_diagnoses
# Out:
# ['G039', 'Q393', 'R635']

# %% [markdown]
# At this point the `icd_codes_curated.xlsx` file needs to be manually curated with these entries.

# %% [markdown]
# ### Import the now curated `icd_codes.xlsx` files to contain now all relevant diagnosis including new ones

# %%
icd_codes = pd.read_excel('/Users/guszti/ventilation_fabian/icd_codes_curated.xlsx', 
                          usecols = [0,1], index_col = 0)

# %% [raw]
# # Now there are no new codes
# sorted(set(icd_all_frme['code']) - set(icd_codes.index))

# %% [markdown]
# ### Create Pathology column with English names

# %%
icd_dictionary = dict(zip(icd_codes.index, icd_codes['name']))

# %%
def icd_replace(lst):
    icd_list = []
    for item in lst:
        new_item = icd_dictionary[item]
        icd_list.append(new_item)
    return icd_list

# %%
clin_df['Pathology_English'] = clin_df['ICD'].apply(icd_replace)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-60-3723ec2f84b4> in <module>
# ----> 1 clin_df['Pathology_English'] = clin_df['ICD'].apply(icd_replace)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, **kwds)
#    4198             else:
#    4199                 values = self.astype(object)._values
# -> 4200                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    4201
#    4202         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas/_libs/lib.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-59-920dc9bf7afd> in icd_replace(lst)
#       2     icd_list = []
#       3     for item in lst:
# ----> 4         new_item = icd_dictionary[item]
#       5         icd_list.append(new_item)
#       6     return icd_list
#
# KeyError: 'Q393'

# %%
clin_df
# Out:
#          Case ID       Date of Birth Gestational Age  Birth Weight  \
# AL000003   42543 2017-03-24 17:41:00        196 days           990
# AL000005   42552 2017-03-26 17:50:00        259 days          3530
# AL000006   42554 2017-03-26 23:37:00        217 days          1470
# AL000007   42578 2017-01-29 00:00:00        280 days          3200
# AL000008   42596 2017-03-29 13:20:00        266 days          3230
# ...          ...                 ...             ...           ...
# AL001054   55383 2020-08-26 09:45:00        273 days          3650
# AL001055   55393 2020-06-17 15:50:00        196 days          1246
# AL001086   55607 2020-09-04 17:56:00        252 days          2860
# AL001095   55736 2020-10-05 18:22:00        287 days          3040
# AL001099   55796 2020-10-12 03:16:00        224 days          1800
#
#          Actual Weight                                          Pathology  \
# AL000003                [Neonat praemat gr s 28 (P07.3)  ,  IRDS (P22....
# AL000005                [Neonat mat gr s 37 (P96.4)  ,  Infectio (P39....
# AL000006                [Neonat praemat gr s 31 (P07.3)  ,  Gemini A (...
# AL000007          4800  [Exsiccatio (E86)  ,  Légzési elégtelenség (P2...
# AL000008                [Neonat mat gr s 38 (P96.4)  ,  Intézeten kívü...
# ...                ...                                                ...
# AL001054                [Neonat mat gr s 39 (P96.4)  ,  Infectio (P39....
# AL001055          3250  [Neonat praemat gr s 28 (P07.3)  ,  BPD (P27.1...
# AL001086          3160  [Neonat praemat gr s 36 (P07.3)  ,  Légzési el...
# AL001095                [Neonat mat gr s 41 (P96.4)  ,  Pneumonia (J18...
# AL001099                [RDS (P22)  ,  Hypothermia (P80.9)  ,  Neonat ...
#
#                                   Start                            End  \
# AL000003  Fri, 24 Mar 2017 180507 +0100  Fri, 24 Mar 2017 195004 +0100
# AL000005  Sun, 26 Mar 2017 191453 +0200  Sun, 26 Mar 2017 195719 +0200
# AL000006  Mon, 27 Mar 2017 000421 +0200  Mon, 27 Mar 2017 005507 +0200
# AL000007  Wed, 29 Mar 2017 004829 +0200  Wed, 29 Mar 2017 024857 +0200
# AL000008  Wed, 29 Mar 2017 154426 +0200  Wed, 29 Mar 2017 174248 +0200
# ...                                 ...                            ...
# AL001054  Wed, 26 Aug 2020 121824 +0200  Wed, 26 Aug 2020 130420 +0200
# AL001055  Thu, 27 Aug 2020 110758 +0200  Thu, 27 Aug 2020 131956 +0200
# AL001086  Mon, 21 Sep 2020 143058 +0200  Mon, 21 Sep 2020 151920 +0200
# AL001095  Tue, 06 Oct 2020 012642 +0200  Tue, 06 Oct 2020 021318 +0200
# AL001099  Mon, 12 Oct 2020 042855 +0200  Mon, 12 Oct 2020 052927 +0200
#
#           Weight     Recording start       Recording end        Duration  \
# AL000003     990 2017-03-24 18:05:07 2017-03-24 19:50:04 0 days 01:44:57
# AL000005    3530 2017-03-26 19:14:53 2017-03-26 19:57:19 0 days 00:42:26
# AL000006    1470 2017-03-27 00:04:21 2017-03-27 00:55:07 0 days 00:50:46
# AL000007    4800 2017-03-29 00:48:29 2017-03-29 02:48:57 0 days 02:00:28
# AL000008    3230 2017-03-29 15:44:26 2017-03-29 17:42:48 0 days 01:58:22
# ...          ...                 ...                 ...             ...
# AL001054    3650 2020-08-26 12:18:24 2020-08-26 13:04:20 0 days 00:45:56
# AL001055    3250 2020-08-27 11:07:58 2020-08-27 13:19:56 0 days 02:11:58
# AL001086    3160 2020-09-21 14:30:58 2020-09-21 15:19:20 0 days 00:48:22
# AL001095    3040                 NaT                 NaT             NaT
# AL001099    1800                 NaT                 NaT             NaT
#
#             Postnatal Age Corrected gestational Age  Gestational Age (weeks)  \
# AL000003  0 days 02:09:04         196 days 02:09:04                     28.0
# AL000005  0 days 02:07:19         259 days 02:07:19                     37.0
# AL000006  0 days 01:18:07         217 days 01:18:07                     31.0
# AL000007 59 days 02:48:57         339 days 02:48:57                     40.0
# AL000008  0 days 04:22:48         266 days 04:22:48                     38.0
# ...                   ...                       ...                      ...
# AL001054  0 days 03:19:20         273 days 03:19:20                     39.0
# AL001055 70 days 21:29:56         266 days 21:29:56                     28.0
# AL001086 16 days 21:23:20         268 days 21:23:20                     36.0
# AL001095              NaT                       NaT                     41.0
# AL001099              NaT                       NaT                     32.0
#
#           Corrected gestational Age (weeks)  \
# AL000003                               28.0
# AL000005                               37.0
# AL000006                               31.0
# AL000007                               48.4
# AL000008                               38.0
# ...                                     ...
# AL001054                               39.0
# AL001055                               38.1
# AL001086                               38.4
# AL001095                                NaN
# AL001099                                NaN
#
#                                              ICD
# AL000003                      [P073, P220, P704]
# AL000005                      [P964, P399, P228]
# AL000006                [P073, P015, Q792, Q205]
# AL000007     [E86, P285, I500, Z518, P964, E141]
# AL000008     [P964, Z381, P219, P90, P708, P809]
# ...                                          ...
# AL001054                     [P964, P399, _0000]
# AL001055   [P073, P271, I270, K409, _0000, P399]
# AL001086  [P073, P285, _0000, Z930, Q288, D4890]
# AL001095               [P964, J189, P228, _0000]
# AL001099          [P22, P809, P073, _0000, P015]
#
# [850 rows x 17 columns]

# %% [markdown]
# ### Final cleanup of the DataFrame

# %%
clin_df.columns
# Out:
# Index(['Case ID', 'Date of Birth', 'Gestational Age', 'Birth Weight',
#        'Actual Weight', 'Pathology', 'Start', 'End', 'Weight',
#        'Recording start', 'Recording end', 'Duration', 'Postnatal Age',
#        'Corrected gestational Age', 'Gestational Age (weeks)',
#        'Corrected gestational Age (weeks)', 'ICD'],
#       dtype='object')

# %%
column_list = ['Case ID', 'Date of Birth', 'Gestational Age (weeks)', 'Birth Weight',
              'Postnatal Age', 'Corrected gestational Age (weeks)',  'Weight',
              'ICD', 'Pathology_English', 'Recording start', 'Recording end', 'Duration',] 
      
clin_df = clin_df[column_list]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-63-13b4fd63318a> in <module>
#       3               'ICD', 'Pathology_English', 'Recording start', 'Recording end', 'Duration',]
#       4
# ----> 5 clin_df = clin_df[column_list]
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2906             if is_iterator(key):
#    2907                 key = list(key)
# -> 2908             indexer = self.loc._get_listlike_indexer(key, axis=1, raise_missing=True)[1]
#    2909
#    2910         # take() does not accept boolean indexers
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1252             keyarr, indexer, new_indexer = ax._reindex_non_unique(keyarr)
#    1253
# -> 1254         self._validate_read_indexer(keyarr, indexer, axis, raise_missing=raise_missing)
#    1255         return keyarr, indexer
#    1256
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py in _validate_read_indexer(self, key, indexer, axis, raise_missing)
#    1302             if raise_missing:
#    1303                 not_found = list(set(key) - set(ax))
# -> 1304                 raise KeyError(f"{not_found} not in index")
#    1305
#    1306             # we skip the warning on Categorical
#
# KeyError: "['Pathology_English'] not in index"

# %%
clin_df.head()
# Out:
#          Case ID       Date of Birth Gestational Age  Birth Weight  \
# AL000003   42543 2017-03-24 17:41:00        196 days           990
# AL000005   42552 2017-03-26 17:50:00        259 days          3530
# AL000006   42554 2017-03-26 23:37:00        217 days          1470
# AL000007   42578 2017-01-29 00:00:00        280 days          3200
# AL000008   42596 2017-03-29 13:20:00        266 days          3230
#
#          Actual Weight                                          Pathology  \
# AL000003                [Neonat praemat gr s 28 (P07.3)  ,  IRDS (P22....
# AL000005                [Neonat mat gr s 37 (P96.4)  ,  Infectio (P39....
# AL000006                [Neonat praemat gr s 31 (P07.3)  ,  Gemini A (...
# AL000007          4800  [Exsiccatio (E86)  ,  Légzési elégtelenség (P2...
# AL000008                [Neonat mat gr s 38 (P96.4)  ,  Intézeten kívü...
#
#                                   Start                            End  \
# AL000003  Fri, 24 Mar 2017 180507 +0100  Fri, 24 Mar 2017 195004 +0100
# AL000005  Sun, 26 Mar 2017 191453 +0200  Sun, 26 Mar 2017 195719 +0200
# AL000006  Mon, 27 Mar 2017 000421 +0200  Mon, 27 Mar 2017 005507 +0200
# AL000007  Wed, 29 Mar 2017 004829 +0200  Wed, 29 Mar 2017 024857 +0200
# AL000008  Wed, 29 Mar 2017 154426 +0200  Wed, 29 Mar 2017 174248 +0200
#
#           Weight     Recording start       Recording end        Duration  \
# AL000003     990 2017-03-24 18:05:07 2017-03-24 19:50:04 0 days 01:44:57
# AL000005    3530 2017-03-26 19:14:53 2017-03-26 19:57:19 0 days 00:42:26
# AL000006    1470 2017-03-27 00:04:21 2017-03-27 00:55:07 0 days 00:50:46
# AL000007    4800 2017-03-29 00:48:29 2017-03-29 02:48:57 0 days 02:00:28
# AL000008    3230 2017-03-29 15:44:26 2017-03-29 17:42:48 0 days 01:58:22
#
#             Postnatal Age Corrected gestational Age  Gestational Age (weeks)  \
# AL000003  0 days 02:09:04         196 days 02:09:04                     28.0
# AL000005  0 days 02:07:19         259 days 02:07:19                     37.0
# AL000006  0 days 01:18:07         217 days 01:18:07                     31.0
# AL000007 59 days 02:48:57         339 days 02:48:57                     40.0
# AL000008  0 days 04:22:48         266 days 04:22:48                     38.0
#
#           Corrected gestational Age (weeks)  \
# AL000003                               28.0
# AL000005                               37.0
# AL000006                               31.0
# AL000007                               48.4
# AL000008                               38.0
#
#                                           ICD
# AL000003                   [P073, P220, P704]
# AL000005                   [P964, P399, P228]
# AL000006             [P073, P015, Q792, Q205]
# AL000007  [E86, P285, I500, Z518, P964, E141]
# AL000008  [P964, Z381, P219, P90, P708, P809]

# %% [markdown]
# ### Statistics on clinical data

# %%
clinical_stats = round(clin_df.describe(percentiles = [0.01, 0.05, 0.25, 0.5, 0.75, 0.95, 0.99]), 1)
clinical_stats
# Out:
#                    Gestational Age  Birth Weight  Weight  \
# count                          850         850.0   850.0
# mean   242 days 18:49:58.588235296        2435.7  2609.7
# std     33 days 22:12:49.083953691        1021.4  1033.0
# min              147 days 00:00:00         300.0   300.0
# 1%               161 days 00:00:00         490.0   569.8
# 5%               175 days 00:00:00         700.0   850.0
# 25%              224 days 00:00:00        1692.5  1850.0
# 50%              252 days 00:00:00        2600.0  2715.0
# 75%              266 days 00:00:00        3200.0  3347.5
# 95%              280 days 00:00:00        3900.0  4205.5
# 99%              287 days 00:00:00        4455.1  4900.0
# max              294 days 00:00:00        5400.0  5920.0
#
#                         Duration                Postnatal Age  \
# count                        792                          792
# mean   0 days 01:17:24.023989898   12 days 19:41:55.128787878
# std    0 days 00:54:51.966850579   30 days 19:50:27.660454673
# min              0 days 00:16:08              0 days 00:01:09
# 1%        0 days 00:20:34.200000       0 days 01:08:43.910000
# 5%        0 days 00:30:05.100000       0 days 01:38:34.850000
# 25%       0 days 00:46:45.750000       0 days 03:07:50.250000
# 50%              0 days 01:07:44              0 days 06:57:55
# 75%              0 days 01:38:41              5 days 18:09:21
# 95%    0 days 02:23:14.499999999   74 days 04:35:51.449999985
# 99%       0 days 03:15:50.750000  138 days 00:55:57.000000024
# max              0 days 19:03:15            231 days 10:33:32
#
#          Corrected gestational Age  Gestational Age (weeks)  \
# count                          792                    850.0
# mean   255 days 21:52:49.674242444                     34.7
# std     41 days 09:38:00.784496699                      4.8
# min              147 days 01:41:03                     21.0
# 1%        167 days 11:07:08.880000                     23.0
# 5%        189 days 14:49:21.500000                     25.0
# 25%       231 days 10:18:43.250000                     32.0
# 50%              259 days 02:24:49                     36.0
# 75%       274 days 05:09:33.750000                     38.0
# 95%       320 days 21:34:31.850000                     40.0
# 99%    386 days 17:57:29.560000008                     41.0
# max              503 days 13:40:44                     42.0
#
#        Corrected gestational Age (weeks)
# count                              792.0
# mean                                36.5
# std                                  5.9
# min                                 21.0
# 1%                                  23.9
# 5%                                  27.1
# 25%                                 33.1
# 50%                                 37.0
# 75%                                 39.2
# 95%                                 45.8
# 99%                                 55.2
# max                                 71.9

# %% [markdown]
# ### Export clinical information data in tables and individual text files

# %% [markdown]
# ##### Create sub-directories for each case if it does not yet exist

# %%
# Images and raw data will be written on an external hard drive
if not os.path.isdir('%s/%s' % (DATA_DUMP, 'fabian_cases')):
    os.makedirs('%s/%s' % (DATA_DUMP, 'fabian_cases'))

for case in sorted(clin_df.index): 
    if not os.path.isdir('%s/%s/%s' % (DATA_DUMP, 'fabian_cases', case)):
        os.makedirs('%s/%s/%s' % (DATA_DUMP, 'fabian_cases', case))

# %% [markdown]
# ##### Export clinical data about individual cases as text files

# %%
# Clinical info about all recordings which clinical data are available and are over 15 minutes long

for case in sorted(clin_df.index):
    
    fileout = open('%s/%s/%s/%s_%s.%s' % (DATA_DUMP, 'fabian_cases', case, case, 'clin_info', 'txt'), 'w')
    
    fileout.write('Case ID:             %-50s\n' % case)
    fileout.write('Start:               %-50s\n' % datetime.strftime(clin_df.loc[case]['Recording start'], 
                                                          '%d/%m/%Y %H:%M:%S', ))
    fileout.write('End:                 %-50s\n' % datetime.strftime(clin_df.loc[case]['Recording end'], 
                                                          '%d/%m/%Y %H:%M:%S', ))
    fileout.write('Duration:            %-50s\n' % clin_df.loc[case]['Duration'])
    fileout.write('Gestational age:     %-50s\n' % clin_df.loc[case]['Gestational Age (weeks)'])
    fileout.write('Postmenstrual age:   %-50s\n' % clin_df.loc[case]['Corrected gestational Age (weeks)'])
    fileout.write('Birth Weight:        %-50s\n' % clin_df.loc[case]['Birth Weight'])
    fileout.write('Weight:              %-50s\n' % clin_df.loc[case]['Weight'])
    fileout.write('ICD:                 %-50s\n' % ', '.join(clin_df.loc[case]['ICD']))
    fileout.write('Diagnoses:           %-50s\n' % ', '.join(clin_df.loc[case]['Pathology_English']))
    
    fileout.close()

# %% [markdown]
# ### Export clinical information as an Excel sheet

# %%
writer = pd.ExcelWriter('%s/%s' % (DIR_WRITE, 'clinical_data_all_1_1100.xlsx'))
clin_df.to_excel(writer, 'clin_df')
writer.save()

# %% [markdown]
# ### Export statistics on clinical data

# %%
writer = pd.ExcelWriter('%s/%s' % (DIR_WRITE, 'clinical_stats_1_1100.xlsx'))
clinical_stats.to_excel(writer, 'stats')
writer.save()

# %% [markdown]
# ### Export processed data as pickle files

# %%
with open('%s/%s.pickle' % (DATA_DUMP, 'clin_df_1_1100'), 'wb') as handle:
    pickle.dump(clin_df, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %% [markdown]
# ### Create patient lists for various disease groups

# %% [markdown]
# ### RDS

# %%
RDS_dg = {'P22', 'P220'}

# %%
RDS_cases = []
for case, dgs in clin_df['ICD'].items():
    if set(dgs).intersection(RDS_dg):
        RDS_cases.append(case)

# %%
print(RDS_cases)

# %%
clin_df_RDS = clin_df.loc[RDS_cases]
clin_df_RDS;

# %%
len(clin_df_RDS)

# %% [markdown]
# ### HIE

# %%
HIE_dg = ['P219', 'Z518', 'Z548',]

# %%
HIE_cases = []
for case, dgs in clin_df['ICD'].items():
    if set(dgs).intersection(HIE_dg):
        HIE_cases.append(case)

# %%
clin_df_HIE = clin_df.loc[HIE_cases]
clin_df_HIE;

# %%
len(clin_df_HIE)

# %% [markdown]
# ### Meconium aspiration

# %%
MAS_dg = ['P240',]

# %%
MAS_cases = []
for case, dgs in clin_df['ICD'].items():
    if set(dgs).intersection(MAS_dg):
        MAS_cases.append(case)

# %%
clin_df_MAS = clin_df.loc[MAS_cases]
clin_df_MAS;

# %%
len(clin_df_MAS)

# %% [markdown]
# ### PPHN

# %%
PPHN_dg = ['P293', ]

# %%
PPHN_cases = []
for case, dgs in clin_df['ICD'].items():
    if set(dgs).intersection(PPHN_dg):
        PPHN_cases.append(case)

# %%
clin_df_PPHN = clin_df.loc[PPHN_cases]
clin_df_PPHN;

# %%
len(clin_df_PPHN)

# %% [markdown]
# ### Congenital diaphragmatic hernia

# %%
CDH_dg = ['Q790', 'Q791']

# %%
CDH_cases = []
for case, dgs in clin_df['ICD'].items():
    if set(dgs).intersection(CDH_dg):
        CDH_cases.append(case)

# %%
clin_df_CDH = clin_df.loc[CDH_cases]
clin_df_CDH;

# %%
len(clin_df_CDH)

# %% [markdown]
# ### Necrotizing enterocolitis (NEC)

# %%
NEC_dg = ['P77',]

# %%
NEC_cases = []
for case, dgs in clin_df['ICD'].items():
    if set(dgs).intersection(NEC_dg):
        NEC_cases.append(case)

# %%
clin_df_NEC = clin_df.loc[NEC_cases]
clin_df_NEC;

# %%
len(clin_df_NEC)

# %% [markdown]
# ### Surgical cases (except NEC, CDH and cardiac)

# %%
surgical_dg = ['K409', 'K562', 'K566', 'K631', 'K9210', 'Q059', 'Q321', 'Q391', 'Q392', 'Q423' , 'Q431',
               'Q438', 'Q4380', 'Q549', 'Q556', 'Q641', 'Q792', 'Q793', 'R1000']

# %%
surgical_cases = []
for case, dgs in clin_df['ICD'].items():
    if set(dgs).intersection(surgical_dg):
        surgical_cases.append(case)

# %%
clin_df_surgical = clin_df.loc[surgical_cases]
clin_df_surgical;

# %%
len(clin_df_surgical)

# %% [markdown]
# ### Cardiac cases (except PFO / ASD)

# %%
cardiac_dg = ['Q201', 'Q203', 'Q205' ,'Q210', 'Q212', 'Q213', 'Q220', 'Q221', 'Q224', 
              'Q228', 'Q232', 'Q234', 'Q240', 'Q244', 'Q245', 'Q251', 'Q252', 'Q253', 'Q254', 'Q262',]

# %%
cardiac_cases = []
for case, dgs in clin_df['ICD'].items():
    if set(dgs).intersection(cardiac_dg):
        cardiac_cases.append(case)

# %%
clin_df_cardiac = clin_df.loc[cardiac_cases]
clin_df_cardiac;

# %%
len(cardiac_dg)

# %% [markdown]
# ### Export clinical dataframes into a multisheet Excel file

# %%
writer = pd.ExcelWriter('%s/%s' % (DIR_WRITE, 'clinical_data_diseases_1_1100.xlsx'))
clin_df.to_excel(writer, 'all')
clin_df_cardiac.to_excel(writer, 'cardiac')
clin_df_CDH.to_excel(writer, 'CDH')
clin_df_HIE.to_excel(writer, 'HIE')
clin_df_MAS.to_excel(writer, 'MAS')
clin_df_NEC.to_excel(writer, 'NEC')
clin_df_PPHN.to_excel(writer, 'PPHN')
clin_df_RDS.to_excel(writer, 'RDS')
clin_df_surgical.to_excel(writer, 'surgical')
writer.save()

# %% [markdown]
# ### Export selected clinical data as pickle archive

# %%
with open('%s/%s.pickle' % (DATA_DUMP, 'clin_df_cardiac'), 'wb') as handle:
    pickle.dump(clin_df_cardiac, handle, protocol=pickle.HIGHEST_PROTOCOL)
    
with open('%s/%s.pickle' % (DATA_DUMP, 'clin_df_CDH'), 'wb') as handle:
    pickle.dump(clin_df_CDH, handle, protocol=pickle.HIGHEST_PROTOCOL)

with open('%s/%s.pickle' % (DATA_DUMP, 'clin_df_HIE'), 'wb') as handle:
    pickle.dump(clin_df_HIE, handle, protocol=pickle.HIGHEST_PROTOCOL)
    
with open('%s/%s.pickle' % (DATA_DUMP, 'clin_df_MAS'), 'wb') as handle:
    pickle.dump(clin_df_MAS, handle, protocol=pickle.HIGHEST_PROTOCOL)

with open('%s/%s.pickle' % (DATA_DUMP, 'clin_df_NEC'), 'wb') as handle:
    pickle.dump(clin_df_NEC, handle, protocol=pickle.HIGHEST_PROTOCOL)
    
with open('%s/%s.pickle' % (DATA_DUMP, 'clin_df_PPHN'), 'wb') as handle:
    pickle.dump(clin_df_PPHN, handle, protocol=pickle.HIGHEST_PROTOCOL)

with open('%s/%s.pickle' % (DATA_DUMP, 'clin_df_RDS'), 'wb') as handle:
    pickle.dump(clin_df_RDS, handle, protocol=pickle.HIGHEST_PROTOCOL)
    
with open('%s/%s.pickle' % (DATA_DUMP, 'clin_df_surgical'), 'wb') as handle:
    pickle.dump(clin_df_surgical, handle, protocol=pickle.HIGHEST_PROTOCOL)
